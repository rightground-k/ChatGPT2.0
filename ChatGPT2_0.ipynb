# %%
pip install -r requirements.txt

# %%
# !python gpt.py
# Out:
# Loading data...
# Initializing model...
# 10.77M parameters
# Training GPU-optimized GPT...
# step    0: train loss 4.4995, val loss 4.5016
# step  200: train loss 2.3816, val loss 2.3960
# step  400: train loss 2.0117, val loss 2.0181
# step  600: train loss 1.7100, val loss 1.7320
# step  800: train loss 1.5372, val loss 1.5675
# step 1000: train loss 1.4309, val loss 1.4710
# step 1200: train loss 1.3691, val loss 1.4145
# step 1400: train loss 1.3254, val loss 1.3688
# step 1600: train loss 1.3019, val loss 1.3527
# step 1800: train loss 1.2800, val loss 1.3349
# step 1999: train loss 1.2738, val loss 1.3225
#
# --- Generating sample text ---
#
#
# “It was not again for my beard,” said Don Quixote. “So not cannot for
# anything to me the duchess worship signs, as I have given upon that I
# have not been any let everymen, and as I know it was a came of for man our
# left my manst will make their money, whose we saw is thou shouldst seek upon it.”
#
# ...
